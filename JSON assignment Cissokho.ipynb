# %%
import pandas as pd

# %%
import json
from pandas.io.json import json_normalize

# %%
#question1

# %%
dataframe = pd.read_json('world_bank_projects.json')

# %%
pd.set_option('display.max_columns',999)
dataframe.head(3)
# Out:
#                                               sector supplementprojectflg  \
# 0  [{'Name': 'Primary education'}, {'Name': 'Seco...                    N
# 1  [{'Name': 'Public administration- Other social...                    N
# 2  [{'Name': 'Rural and Inter-Urban Roads and Hig...                    Y
#
#   projectfinancialtype prodline  \
# 0                  IDA       PE
# 1                OTHER       RE
# 2                  IDA       PE
#
#                                              mjtheme  idacommamt  \
# 0                                [Human development]   130000000
# 1  [Economic management, Social protection and ri...           0
# 2  [Trade and integration, Public sector governan...     6060000
#
#                                   impagency  \
# 0                     MINISTRY OF EDUCATION
# 1                       MINISTRY OF FINANCE
# 2  MINISTRY OF TRANSPORT AND COMMUNICATIONS
#
#                                         project_name mjthemecode  \
# ...

# %%
x = dataframe.countryname.value_counts().head(10)

# %%
x
# Out:
# People's Republic of China         19
# Republic of Indonesia              19
# Socialist Republic of Vietnam      17
# Republic of India                  16
# Republic of Yemen                  13
# People's Republic of Bangladesh    12
# Nepal                              12
# Kingdom of Morocco                 12
# Republic of Mozambique             11
# Africa                             11
# Name: countryname, dtype: int64

# %%
#question2

# %%
theme_search=dataframe['mjtheme_namecode'].head(20)
theme_search
# Out:
# 0     [{'code': '8', 'name': 'Human development'}, {...
# 1     [{'code': '1', 'name': 'Economic management'},...
# 2     [{'code': '5', 'name': 'Trade and integration'...
# 3     [{'code': '7', 'name': 'Social dev/gender/incl...
# 4     [{'code': '5', 'name': 'Trade and integration'...
# 5     [{'code': '6', 'name': 'Social protection and ...
# 6     [{'code': '2', 'name': 'Public sector governan...
# 7     [{'code': '11', 'name': 'Environment and natur...
# 8     [{'code': '10', 'name': 'Rural development'}, ...
# 9     [{'code': '2', 'name': 'Public sector governan...
# 10    [{'code': '10', 'name': 'Rural development'}, ...
# 11    [{'code': '10', 'name': 'Rural development'}, ...
# 12                          [{'code': '4', 'name': ''}]
# 13    [{'code': '5', 'name': 'Trade and integration'...
# 14    [{'code': '6', 'name': 'Social protection and ...
# 15    [{'code': '10', 'name': 'Rural development'}, ...
# 16    [{'code': '10', 'name': 'Rural development'}, ...
# ...

# %%
secondframe = json.load(open('world_bank_projects.json'))

# %%
y = json_normalize(secondframe, 'mjtheme_namecode')
y
# Out:
#      code                                      name
# 0       8                         Human development
# 1      11
# 2       1                       Economic management
# 3       6     Social protection and risk management
# 4       5                     Trade and integration
# ...   ...                                       ...
# 1494   10                         Rural development
# 1495    9                         Urban development
# 1496    8                         Human development
# 1497    5                     Trade and integration
# 1498    4  Financial and private sector development
#
# [1499 rows x 2 columns]

# %%
answer2 = y.name.value_counts()
answer2
# Out:
# Environment and natural resources management    223
# Rural development                               202
# Human development                               197
# Public sector governance                        184
# Social protection and risk management           158
# Financial and private sector development        130
#                                                 122
# Social dev/gender/inclusion                     119
# Trade and integration                            72
# Urban development                                47
# Economic management                              33
# Rule of law                                      12
# Name: name, dtype: int64

# %%
#question3

# %%
thirdframe = json.load(open('world_bank_projects.json'))

# %%
z = json_normalize(thirdframe, 'mjtheme_namecode')
z
# Out:
#      code                                      name
# 0       8                         Human development
# 1      11
# 2       1                       Economic management
# 3       6     Social protection and risk management
# 4       5                     Trade and integration
# ...   ...                                       ...
# 1494   10                         Rural development
# 1495    9                         Urban development
# 1496    8                         Human development
# 1497    5                     Trade and integration
# 1498    4  Financial and private sector development
#
# [1499 rows x 2 columns]

# %%
import numpy as np
pairs = z.drop_duplicates()
pairs['name'].replace('', np.nan, inplace = True)
match = pairs.dropna()
match
# Out:
#                                               name
# code
# 8                                Human development
# 1                              Economic management
# 6            Social protection and risk management
# 5                            Trade and integration
# 2                         Public sector governance
# 11    Environment and natural resources management
# 7                      Social dev/gender/inclusion
# 4         Financial and private sector development
# 10                               Rural development
# 9                                Urban development
# 3                                      Rule of law

# %%
#matchup = dict(zip(match.code,match.name))
#matchup

# %%
final = pd.merge(z,match, on ='code',suffixes =('_x','')).drop('name_x', axis =1)
pd.set_option('display.max_rows',1500)
final.head(50)
# Out:
#                    name
# code
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# 8     Human development
# ...
